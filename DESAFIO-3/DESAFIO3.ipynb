# %% [markdown]
# ## Operadores Relacionais
#
# ![image.png](data:image/png;base64,...)

# %%
## vamos fazer alguns testes

5 == 5
# Out:
# True

# %%
9 == "9"
# Out:
# False

# %%
"9" == "9"
# Out:
# True

# %%
"Hello" == "hello"

## Você notou que as letras maiúsculas contam na comparação?
# Out:
# False

# %%
## Podemos usar parênteses para agrupar as operações
## Vejamos o seguinte:

8 == 9 >= 2 

## Você seria capaz de entender a operação?
## É um pouco difícil né
## Vamos tentar desta forma

(8 == 9) >= 2

## Também podemos agrupar assim:

8 == (9 >= 2)
# Out:
# False

# %% [markdown]
# ## Operadores Lógicos
#
# ![image.png](data:image/png;base64,...)

# %%
8 == 8 or 8 == 9 or 9 == 9
# Out:
# True

# %%
## Da mesma forma, podemos usar parênteses para agrupar as expressões
(9 >= 2) and ("hello" == "hello") and (9 <= 10)
# Out:
# True

# %%
## Vamos brincar um pouco com if-elfi-else

if True:
    print("It is true!")
# Out:
# It is true!

# %%
month = 5

if month == 2:
    print("February")
elif month == 3:
    print("March")
else:
    print("Unknown")
# Out:
# Unknown

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Dado um inteiro **n**, determine se o número é par ou ímpar, se for par, imprima "O número é par" ou "The number is even"

# %%
number = 12

if number

# %% [markdown]
# ### Exercício 2
#
# Em uma cidade do Canadá com climas frios na maioria das vezes, é necessário saber quando você pode sair sem precisar usar casacos, ou seja, quando há sol. Para isso, foi solicitado que você realizasse um programa que determina se as pessoas podem sair sem problemas, então apresentamos a função `input`.

# %%
name = int(input("Write your name: "))

print(name == 25)

## Como você pode ver com a função de entrada, podemos receber a entrada do teclado
## e armazená-los em variáveis.

# %% [markdown]
# na classe a seguir, implemente o método `get_weather`, receba como parâmetro a temperatura do local em graus Fahrenheit, imprima `O clima é ideal para sair sem casaco` se a temperatura for maior ou igual a 65 graus Fahrenheit , caso contrário, imprima `Fique em casa, está frio lá fora`, antes de usar as condicionais converta esse valor para graus Celsius.

# %%
class WeatherMachine:
    
    def get_weather(self, temperature):
        pass

        
weather_machine = WeatherMachine()
weather_machine.get_weather(23)

# %% [markdown]
# # Exercício 3
#
# Se você já viu a série `The Big Bang Theory`, já deve ter ouvido falar do jogo: pedra, papel, tesoura, lagarto, Spock, e se você não conhece as regras, apresentamos abaixo:
#
# ![image.png](data:image/png;base64,...)
#
# O que faremos é implementar uma versão básica do jogo na próxima célula. Você receberá duas entradas que serão **player_1** e **player_2** nessa ordem, por enquanto, considere que você só pode inserir uma das opções válidas listadas acima, imprima quem ganhou com base nas regras e usando as condicionais que já aprendemos.

# %%
player_1 = int(input("Write the value chosen by player 1: "))
player_2 = int(input("Write the value chosen by player 2: "))
## considera apenas como entradas válidas: pedra, papel, tesoura, lagarto, spock

if (1 <= player_1 <= 5 and 1 <= player_2 <= 5) and player_1 == player_2:
  print("EMPATE")
# Out:
# Write the value chosen by player 1: 2
# Write the value chosen by player 2: 2
# ERRO
